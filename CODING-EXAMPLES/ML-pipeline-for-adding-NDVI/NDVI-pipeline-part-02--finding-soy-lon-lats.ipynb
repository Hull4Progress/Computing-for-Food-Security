# %% [markdown]
# ## <span style=color:blue>This notebook builds the function soy_is_here(year,lat,lon), which produces "True" if the 100m x 100m area around lon-lat was a soybean field in the given year.  (At least, according to the data of USDA NASS.)  </span>
#
# ## <span style=color:blue>Then we import the dictionary with the lon-lat sequences for each county, and for each year find the first 20 that are in soybean fields, and right

# %% [markdown]
# <span style=color:blue>First step is to create a function that tests, given a year-lon-lat triple, whether there was a soy field at lat-lon during the given year.  This is based on checking files downloaded from https://www.nass.usda.gov/Research_and_Science/Cropland/Release/index.php.  To understand the meaning of the pixel values, please see https://www.nass.usda.gov/Research_and_Science/Cropland/metadata/meta.php and the files in there, e.g., https://www.nass.usda.gov/Research_and_Science/Cropland/metadata/metadata_ia22.htm.  Among other things, you will see that the value of '5' corresponds to soybean fields </span>

# %%
# first, examining the structure of the files I downloaded

dir_main = '/Users/rick/AG-CODE--v03/CROPSCAPE/DATA-DOWNLOADS/'

# following the structure of the directory name and file from downloaded zip files, which are organized by year
def pathname_for_year(year):
    last_dir_name = f'{str(year)}_30m_cdls/'
    file_name = f'{str(year)}_30m_cdls.tif'
    return dir_main + last_dir_name + file_name

# test
print(pathname_for_year(2022))
# Out:
# /Users/rick/AG-CODE--v03/CROPSCAPE/DATA-DOWNLOADS/2022_30m_cdls/2022_30m_cdls.tif

# %% [markdown]
# <span style=color:blue>Now we inspect structure of the tif files.     </span>
#
# #### <span style=color:blue>Note that the Coordinate Reference System (CRS) is EPSG: 5070 rather than EPSG:4326 (also basically equivalent to WGS84), which is the one we are often using.  BTW, the unit of measure for EPSG:5070 is 1 meter, and so the pixels in these tif files are approximately 30m x 30m.  (See https://epsg.io/5070-1252) </span>

# %%
import json
import subprocess

def pull_useful(ginfo):  # should give as input the result.stdout from calling gdalinfo -json
    useful = {}
    useful['band_count'] = len(ginfo['bands'])
    useful['cornerCoordinates'] = ginfo['cornerCoordinates']
    useful['proj:transform'] = ginfo['stac']['proj:transform']
    useful['size'] = ginfo['size']
    useful['bbox'] = ginfo['stac']['proj:projjson']['bbox']
    useful['espgEncoding'] = ginfo['stac']['proj:epsg']
    return useful

path_to_file = pathname_for_year(2008)
# path_to_file = pathname_for_year(2022)

gdalInfoReq = " ".join(["gdalinfo", "-json", path_to_file])
# print(gdalInfoReq[k])
result = subprocess.run([gdalInfoReq], shell=True, capture_output=True, text=True)
# print(result)
print()
# print(result.stdout)
print()
gdalInfo = json.loads(result.stdout)

useful = pull_useful(gdalInfo)
print(json.dumps(useful, indent=2, sort_keys=True))
# Out:
# {
#   "band_count": 1,
#   "bbox": {
#     "east_longitude": -66.91,
#     "north_latitude": 49.38,
#     "south_latitude": 24.41,
#     "west_longitude": -124.79
#   },
#   "cornerCoordinates": {
#     "center": [
#       -48930.0,
#       1724760.0
#     ],
#     "lowerLeft": [
#       -2356095.0,
#       276915.0
#     ],
#     "lowerRight": [
#       2258235.0,
#       276915.0
#     ],
#     "upperLeft": [
#       -2356095.0,
#       3172605.0
#     ],
#     "upperRight": [
#       2258235.0,
#       3172605.0
#     ]
#   },
#   "espgEncoding": 5070,
#   "proj:transform": [
#     -2356095.0,
#     30.0,
#     0.0,
#     3172605.0,
#     0.0,
#     -30.0
#   ],
#   "size": [
#     153811,
#     96523
#   ]
# }

# %% [markdown]
# <span style=color:blue>Function to transform from EPSG:4326 to EPSG:5070.  The rasterio-based function we use below will take coordinates in EPSG:5010, since the tif files we are using here are in EPSG:5010.     </span>

# %%
from pyproj import Transformer

transformer = Transformer.from_crs('EPSG:4326', 'EPSG:5070')

def from_4326_to_5070(lon,lat):
    # I'm not sure why the role positions of lon-lat are different on input and output
    # but that is what my numerous small test runs showed to me
    new_lon,new_lat = transformer.transform(lat,lon)
    return new_lon, new_lat

# test on coordinates from central Iowa
old_lon = -92.8
old_lat = 42.7
print(from_4326_to_5070(old_lon,old_lat))
# (you can check this at https://epsg.io/transform)
# Out:
# (260567.23440705295, 2193569.032086156)

# %% [markdown]
# <span style=color:blue>Function that fetches a 3x3 square of pixel values from the given tif file.  The pixels in the tif file correspond to  30m x 30m, so we are looking at a rouhgly 100m x 100m area that is all or mostly soybean field </span>
#
# <span style=color:blue>Note that in 2008 the target area was planted mainly with maize, but in 2022 it was planted with soybeans</span>

# %%
import rasterio

# expects lon-lat to be in EPSG:4326.  
# These are converted to EPSG:5070 inside the function
def get_coordinate_pixels(tiff_file, lon, lat):
    dataset = rasterio.open(tiff_file)
    lon_new,lat_new = from_4326_to_5070(lon,lat)
    # print(lon_new,lat_new)
    py, px = dataset.index(lon_new, lat_new)
    # print(py, px)
    # create 3px x 3px window centered on the lon-lat
    window = rasterio.windows.Window(px-1, py-1, 3, 3)
    clip = dataset.read(window=window)
    return clip

    
# test
old_lon = -92.8
old_lat = 42.7
path_to_file = pathname_for_year(2008)
print(get_coordinate_pixels(path_to_file,old_lon,old_lat))
print()
path_to_file = pathname_for_year(2022)
print(get_coordinate_pixels(path_to_file,old_lon,old_lat))
# Out:
# [[[  1   1   1]
#   [  1   1   1]
#   [  1   1 176]]]
#
# [[[5 5 5]
#   [5 5 5]
#   [5 5 5]]]

# %% [markdown]
# <span style=color:blue>Also, a function that that tests whether all 9 spots in the 3x3 square have a given value.  (We are interested in "5", which is soy beans.)</span>

# %%
# land_use_val should be an integer; see, e.g., 
#     https://www.nass.usda.gov/Research_and_Science/Cropland/metadata/metadata_ia22.htm
#     for mapping from values to meanings
def usage_is_here(year, lon, lat, land_use_val):
    path_to_file = pathname_for_year(year)
    arr = get_coordinate_pixels(path_to_file, lon, lat)
    out = True
    for i in range(0,3):
        for j in range(0,3):
            out = out & (arr[0][i][j] == land_use_val)
    return out

def soy_is_here(year, lon, lat):
    return usage_is_here(year,lon,lat,5)

old_lon = -92.8
old_lat = 42.7
print(soy_is_here(2008, old_lon, old_lat))
print(soy_is_here(2022, old_lon, old_lat))
# Out:
# False
# True

# %% [markdown]
# ### <span style=color:blue>Importing the dictionary with lon-lat sequences.  Also setting a second dict that will hold lists lon-lats that are in soybean fields.</span>

# %%
archive_dir = '/Users/rick/AG-CODE--v03/ML-ARCHIVES--v01/'
in_file = 'state_county__seq_of_lon_lats.json'

f = open(archive_dir + in_file)
dict = json.load(f)

print(dict.keys())
# Out:
# dict_keys(['ILLINOIS', 'INDIANA', 'IOWA', 'MISSOURI', 'NEBRASKA', 'OHIO'])

# %% [markdown]
# <span style=color:blue>Function that scans through one list of lon-lats and finds first set that are in soybean fields</span>

# %%
def gen_soy_lon_lats(year,state,county, count):
    list = dict[state][county]
    i = 0
    out_list = []
    for ll in list:
        if soy_is_here(year, ll[0], ll[1]):
            out_list += [ll]
            i += 1
        if i == 20:
            return out_list, []
    print(f'\nFor {str(year)}, {state}, {county}: \nFailed to find {str(count)} lon-lats that were in soybean fields. Found only {str(i)}.\n')
    short_fall_record = [year, state, county, i]
    return out_list, short_fall_record

list, short = gen_soy_lon_lats(2008, 'ILLINOIS', 'MASSAC', 20)
print(list)
print(short)
print()
list, short = gen_soy_lon_lats(2008, 'MISSOURI', 'DALLAS', 20)
print(list)
print(short)
# Out:
# [[-89.1984554, 36.7738721], [-88.9657046, 36.7313958], [-88.819793, 36.8675512], [-88.6325773, 36.7654643], [-88.9978016, 37.6782879], [-89.1806347, 36.8884787], [-89.0443054, 37.2258879], [-88.7746352, 37.2689221], [-88.5048973, 36.9437909], [-89.108685, 37.5181656], [-88.6325461, 36.754499], [-88.81078, 36.8124781], [-89.1819939, 36.787544], [-88.6579458, 36.9255517], [-88.2954249, 36.7502558], [-88.786367, 37.0459674], [-88.6205757, 36.7924507], [-88.9235313, 37.3041449], [-88.6585063, 37.6831332], [-88.7716353, 37.2425947]]
# []
#
#
# For 2008, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
# [[-93.4923439, 37.5926585], [-93.3564492, 37.4714198]]
# [2008, 'MISSOURI', 'DALLAS', 2]

# %% [markdown]
# <span style=color:blue>Function that generates a fixed number of lon-lats in soybean fields for each year and each county. This took quite a while to run completely -- about 4 hours.    </span>

# %%
import datetime

working_dir = '/Users/rick/AG-CODE--v03/ML-WITH-NDVI/OUTPUTS/OUTPUT-v01/'
dict1_file = 'year_state_county_soy_seq.json'
short_list = 'year_state_county_shortfalls.json'

def gen_all_soy_lists(dict, count):
    dict1 = {}
    for year in range(2008,2023):
        dict1[year] = {}
        for key in dict.keys():
            dict1[year][key] = {}    
    print(dict1.keys())
    print(dict1[2013].keys())
    
    shortfall_list = []

    i = 0
    for year in dict1.keys():
        for state in dict.keys():
            for county in dict[state].keys():
                list, short = gen_soy_lon_lats(year, state, county, count)
                dict1[year][state][county] = list
                if short != []:
                    shortfall_list += [short]
                                
                i += 1
                if i % 20 == 0:
                    print(f'Have generated soybean lon-lat lists for {str(i)} year-county pairs')
                if i % 50 == 0:
                    with open(working_dir + dict1_file, 'w') as fp:
                        json.dump(dict1, fp)
                    with open(working_dir + short_list, 'w') as fp:
                        json.dump(shortfall_list, fp)
                
    return dict1, shortfall_list
                    
print(datetime.datetime.now())
dict1, short = gen_all_soy_lists(dict, 20)
print(datetime.datetime.now())
# Out:
# 2023-05-28 22:20:00.031447
# dict_keys([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022
MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2009, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2009, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2009, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
#
# For 2009, MISSOURI, MCDONALD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 13.
#
# Have generated soybean lon-lat lists for 940 year-county pairs
#
# For 2009, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2009, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2009, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
#
# For 2009, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2009, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2009, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 960 year-county pairs
# Have generated soybean lon-lat lists for 980 year-county pairs
# Have generated soybean lon-lat lists for 1000 year-county pairs
#
# For 2009, NEBRASKA, DUNDY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 16.
#
# Have generated soybean lon-lat lists for 1020 year-county pairs
# Have generated soybean lon-lat lists for 1040 year-county pairs
# Have generated soybean lon-lat lists for 1060 year-county pairs
# Have generated soybean lon-lat lists for 1080 year-county pairs
#
# For 2009, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
# Have generated soybean lon-lat lists for 1100 year-county pairs
#
# For 2009, OHIO, GALLIA:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
#
# For 2009, OHIO, GUERNSEY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 16.
#
#
# For 2009, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2009, OHIO, MORGAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
#
# For 2009, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
#
# For 2009, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
# Have generated soybean lon-lat lists for 1120 year-county pairs
# Have generated soybean lon-lat lists for 1140 year-county pairs
# Have generated soybean lon-lat lists for 1160 year-county pairs
# Have generated soybean lon-lat lists for 1180 year-county pairs
# Have generated soybean lon-lat lists for 1200 year-county pairs
# Have generated soybean lon-lat lists for 1220 year-county pairs
# Have generated soybean lon-lat lists for 1240 year-county pairs
# Have generated soybean lon-lat lists for 1260 year-county pairs
# Have generated soybean lon-lat lists for 1280 year-county pairs
# Have generated soybean lon-lat lists for 1300 year-county pairs
# Have generated soybean lon-lat lists for 1320 year-county pairs
# Have generated soybean lon-lat lists for 1340 year-county pairs
# Have generated soybean lon-lat lists for 1360 year-county pairs
# Have generated soybean lon-lat lists for 1380 year-county pairs
# Have generated soybean lon-lat lists for 1400 year-county pairs
# Have generated soybean lon-lat lists for 1420 year-county pairs
# Have generated soybean lon-lat lists for 1440 year-county pairs
# Have generated soybean lon-lat lists for 1460 year-county pairs
#
# For 2010, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
#
# For 2010, MISSOURI, LACLEDE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2010, MISSOURI, PHELPS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2010, MISSOURI, POLK:
# Failed to find 20 lon-lats that were in soybean fields. Found only 12.
#
#
# For 2010, MISSOURI, PULASKI:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
#
# For 2010, MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
# Have generated soybean lon-lat lists for 1480 year-county pairs
#
# For 2010, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2010, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
#
# For 2010, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2010, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2010, MISSOURI, MCDONALD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
# Have generated soybean lon-lat lists for 1500 year-county pairs
#
# For 2010, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
#
# For 2010, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2010, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2010, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2010, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2010, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 1520 year-county pairs
# Have generated soybean lon-lat lists for 1540 year-county pairs
# Have generated soybean lon-lat lists for 1560 year-county pairs
# Have generated soybean lon-lat lists for 1580 year-county pairs
# Have generated soybean lon-lat lists for 1600 year-county pairs
#
# For 2010, OHIO, LAKE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 13.
#
# Have generated soybean lon-lat lists for 1620 year-county pairs
# Have generated soybean lon-lat lists for 1640 year-county pairs
#
# For 2010, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2010, OHIO, HARRISON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
#
# For 2010, OHIO, JEFFERSON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
# Have generated soybean lon-lat lists for 1660 year-county pairs
#
# For 2010, OHIO, GALLIA:
# Failed to find 20 lon-lats that were in soybean fields. Found only 16.
#
#
# For 2010, OHIO, GUERNSEY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
#
# For 2010, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
#
# For 2010, OHIO, MORGAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
#
# For 2010, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2010, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 11.
#
# Have generated soybean lon-lat lists for 2600 year-county pairs
#
# For 2012, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2012, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
#
# For 2012, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2012, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
#
# For 2012, MISSOURI, MCDONALD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
# Have generated soybean lon-lat lists for 2620 year-county pairs
#
# For 2012, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
#
# For 2012, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2012, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2012, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2012, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2012, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 2640 year-county pairs
# Have generated soybean lon-lat lists for 2660 year-county pairs
# Have generated soybean lon-lat lists for 2680 year-county pairs
#
# For 2012, NEBRASKA, DUNDY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 12.
#
# Have generated soybean lon-lat lists for 2700 year-county pairs
# Have generated soybean lon-lat lists for 2720 year-county pairs
# Have generated soybean lon-lat lists for 2740 year-county pairs
# Have generated soybean lon-lat lists for 2760 year-county pairs
#
# For 2012, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
#
# For 2012, OHIO, HARRISON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
#
# For 2012, OHIO, GALLIA:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
# Have generated soybean lon-lat lists for 2780 year-county pairs
#
# For 2012, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 16.
#
#
# For 2012, OHIO, MORGAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2012, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
#
# For 2012, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
# Have generated soybean lon-lat lists for 2800 year-county pairs
# Have generated soybean lon-lat lists for 2820 year-county pairs
# Have generated soybean lon-lat lists for 2840 year-county pairs
# Have generated soybean lon-lat lists for 2860 year-county pairs
# Have generated soybean lon-lat lists for 2880 year-county pairs
# Have generated soybean lon-lat lists for 2900 year-county pairs
# Have generated soybean lon-lat lists for 2920 year-county pairs
# Have generated soybean lon-lat lists for 2940 year-county pairs
# Have generated soybean lon-lat lists for 2960 year-county pairs
# Have generated soybean lon-lat lists for 2980 year-county pairs
# Have generated soybean lon-lat lists for 3000 year-county pairs
# Have generated soybean lon-lat lists for 3020 year-county pairs
# Have generated soybean lon-lat lists for 3040 year-county pairs
# Have generated soybean lon-lat lists for 3060 year-county pairs
# Have generated soybean lon-lat lists for 3080 year-county pairs
# Have generated soybean lon-lat lists for 3100 year-county pairs
# Have generated soybean lon-lat lists for 3120 year-county pairs
#
# For 2013, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
# Have generated soybean lon-lat lists for 3140 year-county pairs
#
# For 2013, MISSOURI, LACLEDE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2013, MISSOURI, PHELPS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2013, MISSOURI, POLK:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2013, MISSOURI, PULASKI:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2013, MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
# Have generated soybean lon-lat lists for 3160 year-county pairs
#
# For 2013, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2013, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
#
# For 2013, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
#
# For 2013, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
#
# For 2013, MISSOURI, MCDONALD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2013, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 3180 year-county pairs
# For 2013, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2013, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
#
# For 2013, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2013, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2013, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
# Have generated soybean lon-lat lists for 3200 year-county pairs
# Have generated soybean lon-lat lists for 3220 year-county pairs
# Have generated soybean lon-lat lists for 3240 year-county pairs
#
# For 2013, NEBRASKA, DUNDY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
# Have generated soybean lon-lat lists for 3260 year-county pairs
# Have generated soybean lon-lat lists for 3280 year-county pairs
# Have generated soybean lon-lat lists for 3300 year-county pairs
# Have generated soybean lon-lat lists for 3320 year-county pairs
#
# For 2013, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2013, OHIO, JEFFERSON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 11.
#
#
# For 2013, OHIO, GALLIA:
# Failed to find 20 lon-lats that were in soybean fields. Found only 12.
#
# Have generated soybean lon-lat lists for 3340 year-county pairs
#
# For 2013, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2013, OHIO, MORGAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 14.
#
#
# For 2013, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2013, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
# Have generated soybean lon-lat lists for 5220 year-county pairs
# Have generated soybean lon-lat lists for 5240 year-county pairs
# Have generated soybean lon-lat lists for 5260 year-county pairs
# Have generated soybean lon-lat lists for 5280 year-county pairs
# Have generated soybean lon-lat lists for 5300 year-county pairs
# Have generated soybean lon-lat lists for 5320 year-county pairs
# Have generated soybean lon-lat lists for 5340 year-county pairs
# Have generated soybean lon-lat lists for 5360 year-county pairs
#
# For 2017, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2017, MISSOURI, LACLEDE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
# Have generated soybean lon-lat lists for 5380 year-county pairs
#
# For 2017, MISSOURI, PHELPS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2017, MISSOURI, PULASKI:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2017, MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
# Have generated soybean lon-lat lists for 5400 year-county pairs
#
# For 2017, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
#
# For 2017, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 14.
#
#
# For 2017, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
#
# For 2017, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
#
# For 2017, MISSOURI, MCDONALD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
#
# For 2017, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
# Have generated soybean lon-lat lists for 5420 year-county pairs
# For 2017, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
#
# For 2017, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2017, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2017, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 5440 year-county pairs
# Have generated soybean lon-lat lists for 5460 year-county pairs
# Have generated soybean lon-lat lists for 5480 year-county pairs
# Have generated soybean lon-lat lists for 5500 year-county pairs
# Have generated soybean lon-lat lists for 5520 year-county pairs
# Have generated soybean lon-lat lists for 5540 year-county pairs
#
# For 2017, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
# Have generated soybean lon-lat lists for 5560 year-county pairs
# Have generated soybean lon-lat lists for 5580 year-county pairs
#
# For 2017, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
#
# For 2017, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2017, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
# Have generated soybean lon-lat lists for 5600 year-county pairs
# Have generated soybean lon-lat lists for 5620 year-county pairs
# Have generated soybean lon-lat lists for 5640 year-county pairs
# Have generated soybean lon-lat lists for 5660 year-county pairs
# Have generated soybean lon-lat lists for 5680 year-county pairs
# Have generated soybean lon-lat lists for 5700 year-county pairs
# Have generated soybean lon-lat lists for 5720 year-county pairs
# Have generated soybean lon-lat lists for 5740 year-county pairs
# Have generated soybean lon-lat lists for 5760 year-county pairs
# Have generated soybean lon-lat lists for 5780 year-county pairs
# Have generated soybean lon-lat lists for 5800 year-county pairs
# Have generated soybean lon-lat lists for 5820 year-county pairs
# Have generated soybean lon-lat lists for 5840 year-county pairs
# Have generated soybean lon-lat lists for 5860 year-county pairs
# Have generated soybean lon-lat lists for 5880 year-county pairs
# Have generated soybean lon-lat lists for 5900 year-county pairs
# Have generated soybean lon-lat lists for 5920 year-county pairs
#
# For 2018, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2018, MISSOURI, LACLEDE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
# Have generated soybean lon-lat lists for 5940 year-county pairs
#
# For 2018, MISSOURI, PHELPS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2018, MISSOURI, POLK:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
#
# For 2018, MISSOURI, PULASKI:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2018, MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 13.
#
# Have generated soybean lon-lat lists for 5960 year-county pairs
#
# For 2018, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2018, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
#
# For 2018, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
#
# For 2018, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2018, MISSOURI, MCDONALD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2018, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
# Have generated soybean lon-lat lists for 5980 year-county pairs
#
# For 2018, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2018, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 11.
#
#
# For 2018, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2018, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2018, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 6000 year-county pairs
# Have generated soybean lon-lat lists for 6020 year-county pairs
# Have generated soybean lon-lat lists for 6040 year-county pairs
# Have generated soybean lon-lat lists for 6060 year-county pairs
# Have generated soybean lon-lat lists for 6080 year-county pairs
# Have generated soybean lon-lat lists for 6100 year-county pairs
#
# For 2018, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2018, OHIO, HARRISON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 19.
#
# Have generated soybean lon-lat lists for 6120 year-county pairs
#
# For 2018, OHIO, GALLIA:
# Failed to find 20 lon-lats that were in soybean fields. Found only 16.
#
# Have generated soybean lon-lat lists for 6140 year-county pairs
#
# For 2018, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2018, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2018, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
# Have generated soybean lon-lat lists for 6160 year-county pairs
# Have generated soybean lon-lat lists for 6180 year-county pairs
# Have generated soybean lon-lat lists for 6200 year-county pairs
# Have generated soybean lon-lat lists for 6220 year-county pairs
# Have generated soybean lon-lat lists for 6240 year-county pairs
# Have generated soybean lon-lat lists for 6260 year-county pairs
# Have generated soybean lon-lat lists for 6280 year-county pairs
# Have generated soybean lon-lat lists for 6300 year-county pairs
# Have generated soybean lon-lat lists for 6320 year-county pairs
# Have generated soybean lon-lat lists for 6340 year-county pairs
# Have generated soybean lon-lat lists for 6360 year-county pairs
# Have generated soybean lon-lat lists for 6380 year-county pairs
# Have generated soybean lon-lat lists for 6400 year-county pairs
# Have generated soybean lon-lat lists for 6420 year-county pairs
# Have generated soybean lon-lat lists for 6440 year-county pairs
# Have generated soybean lon-lat lists for 6460 year-county pairs
# Have generated soybean lon-lat lists for 6480 year-county pairs
#
# For 2019, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2019, MISSOURI, LACLEDE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
# Have generated soybean lon-lat lists for 6500 year-county pairs
#
# For 2019, MISSOURI, PHELPS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2019, MISSOURI, POLK:
# Failed to find 20 lon-lats that were in soybean fields. Found only 12.
#
#
# For 2019, MISSOURI, PULASKI:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2019, MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 14.
#
#
# For 2019, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 12.
#
# Have generated soybean lon-lat lists for 6520 year-county pairs
#
# For 2019, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 13.
#
#
# For 2019, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2019, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2019, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 6540 year-county pairs
#
# For 2019, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2019, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
#
# For 2019, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2019, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
# For 2019, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
# Have generated soybean lon-lat lists for 6560 year-county pairs
# Have generated soybean lon-lat lists for 6580 year-county pairs
# Have generated soybean lon-lat lists for 6600 year-county pairs
# Have generated soybean lon-lat lists for 6620 year-county pairs
# Have generated soybean lon-lat lists for 6640 year-county pairs
# Have generated soybean lon-lat lists for 6660 year-county pairs
#
# For 2019, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
# Have generated soybean lon-lat lists for 6680 year-county pairs
#
# For 2019, OHIO, JEFFERSON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 16.
#
# Have generated soybean lon-lat lists for 6700 year-county pairs
#
# For 2019, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
#
# For 2019, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
#
# For 2019, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
# Have generated soybean lon-lat lists for 6720 year-county pairs
# Have generated soybean lon-lat lists for 6740 year-county pairs
# Have generated soybean lon-lat lists for 6760 year-county pairs
# Have generated soybean lon-lat lists for 6780 year-county pairs
# Have generated soybean lon-lat lists for 6800 year-county pairs
# Have generated soybean lon-lat lists for 6820 year-county pairs
# Have generated soybean lon-lat lists for 6840 year-county pairs
# Have generated soybean lon-lat lists for 6860 year-county pairs
# Have generated soybean lon-lat lists for 6880 year-county pairs
# Have generated soybean lon-lat lists for 6900 year-county pairs
# Have generated soybean lon-lat lists for 6920 year-county pairs
# Have generated soybean lon-lat lists for 6940 year-county pairs
# Have generated soybean lon-lat lists for 6960 year-county pairs
# Have generated soybean lon-lat lists for 6980 year-county pairs
# Have generated soybean lon-lat lists for 7000 year-county pairs
# Have generated soybean lon-lat lists for 7020 year-county pairs
# Have generated soybean lon-lat lists for 7040 year-county pairs
#
# For 2020, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2020, MISSOURI, LACLEDE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
# Have generated soybean lon-lat lists for 7060 year-county pairs
#
# For 2020, MISSOURI, PHELPS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2020, MISSOURI, POLK:
# Failed to find 20 lon-lats that were in soybean fields. Found only 11.
#
#
# For 2020, MISSOURI, PULASKI:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2020, MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2020, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 16.
#
#
# For 2020, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
# Have generated soybean lon-lat lists for 7080 year-county pairs
#
# For 2020, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
#
# For 2020, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
#
# For 2020, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 7100 year-county pairs
#
# For 2020, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
#
# For 2020, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2020, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
#
# For 2020, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
#
# For 2020, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 0.
#
# Have generated soybean lon-lat lists for 7120 year-county pairs
# Have generated soybean lon-lat lists for 7140 year-county pairs
# Have generated soybean lon-lat lists for 7160 year-county pairs
# Have generated soybean lon-lat lists for 7180 year-county pairs
# Have generated soybean lon-lat lists for 7200 year-county pairs
# Have generated soybean lon-lat lists for 7220 year-county pairs
#
# For 2020, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
# Have generated soybean lon-lat lists for 7240 year-county pairs
#
# For 2020, OHIO, GALLIA:
# Failed to find 20 lon-lats that were in soybean fields. Found only 19.
#
# Have generated soybean lon-lat lists for 7260 year-county pairs
#
# For 2020, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 15.
#
#
# For 2020, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
# Have generated soybean lon-lat lists for 7280 year-county pairs
# Have generated soybean lon-lat lists for 7300 year-county pairs
# Have generated soybean lon-lat lists for 7320 year-county pairs
# Have generated soybean lon-lat lists for 7340 year-county pairs
# Have generated soybean lon-lat lists for 7360 year-county pairs
# Have generated soybean lon-lat lists for 7380 year-county pairs
# Have generated soybean lon-lat lists for 7400 year-county pairs
# Have generated soybean lon-lat lists for 7420 year-county pairs
# Have generated soybean lon-lat lists for 7440 year-county pairs
# Have generated soybean lon-lat lists for 7460 year-county pairs
# Have generated soybean lon-lat lists for 7480 year-county pairs
# Have generated soybean lon-lat lists for 7500 year-county pairs
# Have generated soybean lon-lat lists for 7520 year-county pairs
# Have generated soybean lon-lat lists for 7540 year-county pairs
# Have generated soybean lon-lat lists for 7560 year-county pairs
# Have generated soybean lon-lat lists for 7580 year-county pairs
# Have generated soybean lon-lat lists for 7600 year-county pairs
#
# For 2021, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2021, MISSOURI, LACLEDE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
# Have generated soybean lon-lat lists for 7620 year-county pairs
#
# For 2021, MISSOURI, PHELPS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 12.
#
#
# For 2021, MISSOURI, PULASKI:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2021, MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2021, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 14.
#
#
# For 2021, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
# Have generated soybean lon-lat lists for 7640 year-county pairs
#
# For 2021, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2021, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2021, MISSOURI, MCDONALD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 12.
#
#
# For 2021, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 7660 year-county pairs
#
# For 2021, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2021, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 13.
#
#
# For 2021, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2021, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
#
# For 2021, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 2.
#
# Have generated soybean lon-lat lists for 7680 year-county pairs
# Have generated soybean lon-lat lists for 7700 year-county pairs
# Have generated soybean lon-lat lists for 7720 year-county pairs
# Have generated soybean lon-lat lists for 7740 year-county pairs
# Have generated soybean lon-lat lists for 7760 year-county pairs
# Have generated soybean lon-lat lists for 7780 year-county pairs
# For 2021, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 7.
#
# Have generated soybean lon-lat lists for 7800 year-county pairs
#
# For 2021, OHIO, GALLIA:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
#
# For 2021, OHIO, MEIGS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 13.
#
# Have generated soybean lon-lat lists for 7820 year-county pairs
#
# For 2021, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2021, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
# Have generated soybean lon-lat lists for 7840 year-county pairs
# Have generated soybean lon-lat lists for 7860 year-county pairs
# Have generated soybean lon-lat lists for 7880 year-county pairs
# Have generated soybean lon-lat lists for 7900 year-county pairs
# Have generated soybean lon-lat lists for 7920 year-county pairs
# Have generated soybean lon-lat lists for 7940 year-county pairs
# Have generated soybean lon-lat lists for 7960 year-county pairs
# Have generated soybean lon-lat lists for 7980 year-county pairs
# Have generated soybean lon-lat lists for 8000 year-county pairs
# Have generated soybean lon-lat lists for 8020 year-county pairs
# Have generated soybean lon-lat lists for 8040 year-county pairs
# Have generated soybean lon-lat lists for 8060 year-county pairs
# Have generated soybean lon-lat lists for 8080 year-county pairs
# Have generated soybean lon-lat lists for 8100 year-county pairs
# Have generated soybean lon-lat lists for 8120 year-county pairs
# Have generated soybean lon-lat lists for 8140 year-county pairs
# Have generated soybean lon-lat lists for 8160 year-county pairs
#
# For 2022, MISSOURI, DALLAS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
#
# For 2022, MISSOURI, LACLEDE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
# Have generated soybean lon-lat lists for 8180 year-county pairs
#
# For 2022, MISSOURI, PHELPS:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2022, MISSOURI, POLK:
# Failed to find 20 lon-lats that were in soybean fields. Found only 16.
#
#
# For 2022, MISSOURI, PULASKI:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2022, MISSOURI, CRAWFORD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 14.
#
#
# For 2022, MISSOURI, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 14.
#
#
# For 2022, MISSOURI, BARRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
#
# For 2022, MISSOURI, CHRISTIAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
# Have generated soybean lon-lat lists for 8200 year-county pairs
#
# For 2022, MISSOURI, GREENE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 8.
#
#
# For 2022, MISSOURI, MCDONALD:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
#
# For 2022, MISSOURI, WEBSTER:
# Failed to find 20 lon-lats that were in soybean fields. Found only 1.
#
#
# For 2022, NEBRASKA, CHEYENNE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 3.
#
# Have generated soybean lon-lat lists for 8220 year-county pairs
#
# For 2022, NEBRASKA, DEUEL:
# Failed to find 20 lon-lats that were in soybean fields. Found only 17.
#
#
# For 2022, NEBRASKA, GARDEN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 6.
#
#
# For 2022, NEBRASKA, SHERIDAN:
# Failed to find 20 lon-lats that were in soybean fields. Found only 9.
#
#
# For 2022, NEBRASKA, CHERRY:
# Failed to find 20 lon-lats that were in soybean fields. Found only 5.
#
# Have generated soybean lon-lat lists for 8240 year-county pairs
# Have generated soybean lon-lat lists for 8260 year-county pairs
# Have generated soybean lon-lat lists for 8280 year-county pairs
# Have generated soybean lon-lat lists for 8300 year-county pairs
# Have generated soybean lon-lat lists for 8320 year-county pairs
# Have generated soybean lon-lat lists for 8340 year-county pairs
#
# For 2022, OHIO, BELMONT:
# Failed to find 20 lon-lats that were in soybean fields. Found only 10.
#
# Have generated soybean lon-lat lists for 8360 year-county pairs
# Have generated soybean lon-lat lists for 8380 year-county pairs
#
# For 2022, OHIO, NOBLE:
# Failed to find 20 lon-lats that were in soybean fields. Found only 18.
#
#
# For 2022, OHIO, WASHINGTON:
# Failed to find 20 lon-lats that were in soybean fields. Found only 4.
#
# 2023-05-29 02:14:05.575842

# %% [markdown]
# <span style=color:blue>Save the dict1 and also the shortfalls    </span>

# %%
archive_dir = '/Users/rick/AG-CODE--v03/ML-ARCHIVES--v01/'
dict1_file = 'year_state_county_soy_seq.json'
short_list = 'year_state_county_shortfalls.json'

with open(archive_dir + dict1_file, 'w') as fp:
    json.dump(dict1, fp)
with open(archive_dir + short_list, 'w') as fp:
    json.dump(short, fp)

# %% [markdown]
# <span style=color:blue>Collecting year-state-county with zero hits </span>

# %%
zero_falls = []

for l in short:
    if l[3] == 0:
        zero_falls += [[l]]
        
print(len(zero_falls))

print(json.dumps(zero_falls,indent=4))

archive_dir = '/Users/rick/AG-CODE--v03/ML-ARCHIVES--v01/'
zero_file = 'year_state_county_soy_zero_falls.json'
with open(archive_dir + zero_file, 'w') as fp:
    json.dump(zero_falls, fp)
# Out:
# 32
# [
#     [
#         [
#             2008,
#             "MISSOURI",
#             "CHRISTIAN",
#             0
#         ]
#     ],
#     [
#         [
#             2008,
#             "MISSOURI",
#             "WEBSTER",
#             0
#         ]
#     ],
#     [
#         [
#             2008,
#             "NEBRASKA",
#             "GARDEN",
#             0
#         ]
#     ],
#     [
#         [
#             2008,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2008,
#             "OHIO",
#             "WASHINGTON",
#             0
#         ]
#     ],
#     [
#         [
#             2009,
#             "NEBRASKA",
#             "CHEYENNE",
#             0
#         ]
#     ],
#     [
#         [
#             2009,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2010,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2011,
#             "MISSOURI",
#             "CHRISTIAN",
#             0
#         ]
#     ],
#     [
#         [
#             2011,
#             "NEBRASKA",
#             "CHEYENNE",
#             0
#         ]
#     ],
#     [
#         [
#             2011,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2011,
#             "NEBRASKA",
#             "CHERRY",
#             0
#         ]
#     ],
#     [
#         [
#             2012,
#             "NEBRASKA",
#             "CHEYENNE",
#             0
#         ]
#     ],
#     [
#         [
#             2012,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2013,
#             "NEBRASKA",
#             "CHEYENNE",
#             0
#         ]
#     ],
#     [
#         [
#             2013,
#             "NEBRASKA",
#             "GARDEN",
#             0
#         ]
#     ],
#     [
#         [
#             2013,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2013,
#             "NEBRASKA",
#             "CHERRY",
#             0
#         ]
#     ],
#     [
#         [
#             2014,
#             "MISSOURI",
#             "CHRISTIAN",
#             0
#         ]
#     ],
#     [
#         [
#             2014,
#             "NEBRASKA",
#             "CHEYENNE",
#             0
#         ]
#     ],
#     [
#         [
#             2014,
#             "NEBRASKA",
#             "GARDEN",
#             0
#         ]
#     ],
#     [
#         [
#             2014,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2014,
#             "NEBRASKA",
#             "CHERRY",
#             0
#         ]
#     ],
#     [
#         [
#             2015,
#             "NEBRASKA",
#             "GARDEN",
#             0
#         ]
#     ],
#     [
#         [
#             2015,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2016,
#             "NEBRASKA",
#             "SHERIDAN",
#             0
#         ]
#     ],
#     [
#         [
#             2018,
#             "MISSOURI",
#             "WEBSTER",
#             0
#         ]
#     ],
#     [
#         [
#             2018,
#             "NEBRASKA",
#             "GARDEN",
#             0
#         ]
#     ],
#     [
#         [
#             2019,
#             "MISSOURI",
#             "CHRISTIAN",
#             0
#         ]
#     ],
#     [
#         [
#             2019,
#             "NEBRASKA",
#             "CHEYENNE",
#             0
#         ]
#     ],
#     [
#         [
#             2020,
#             "MISSOURI",
#             "CHRISTIAN",
#             0
#         ]
#     ],
#     [
#         [
#             2020,
#             "NEBRASKA",
#             "CHERRY",
#             0
#         ]
#     ]
# ]

# %% [markdown]
# <span style=color:blue>Checking if any year-state-county in zero_falls had a positive yield in year_state_county_yield table</span>

# %%
import pandas as pd

archive_dir = '/Users/rick/AG-CODE--v03/ML-ARCHIVES--v01/'
yscy_file = 'year_state_county_yield.csv'

df_yscy = pd.read_csv(archive_dir + yscy_file)
print('Top of df_yscy')
print(df_yscy.head())

zero_with_yield = []
for l in zero_falls:
    year = l[0][0]
    state = l[0][1]
    county = l[0][2]
    rows = df_yscy[(df_yscy['year'] == year) & \
                  (df_yscy['state_name'] == state) & \
                  (df_yscy['county_name'] == county)]
    if len(rows) > 0:
        y = rows['yield'].iloc[0]
        zero_with_yield += [{'year':year, 'state_name':state, \
                             'county_name':county, 'yield':y}]

print('\nLength of zero_with_yield is: ', len(zero_with_yield))
print('\nListing of zero_with_yield')
df_zwy = pd.DataFrame(zero_with_yield)
print(df_zwy.head(30))
    
zero_with_yield = 'year_state_county_soy_zero_with_yield.csv'
df_zwy.to_csv(archive_dir + zero_with_yield, index=False)
# Out:
# Top of df_yscy
#    year state_name county_name  yield
# 0  2022   ILLINOIS      BUREAU   67.5
# 1  2021   ILLINOIS      BUREAU   66.4
# 2  2020   ILLINOIS      BUREAU   64.8
# 3  2019   ILLINOIS      BUREAU   57.4
# 4  2018   ILLINOIS      BUREAU   68.5
#
# Length of zero_with_yield is:  8
#
# Listing of zero_with_yield
#    year state_name county_name  yield
# 0  2008   MISSOURI     WEBSTER   43.0
# 1  2008       OHIO  WASHINGTON   36.5
# 2  2011   NEBRASKA    CHEYENNE   40.4
# 3  2013   NEBRASKA    CHEYENNE   38.6
# 4  2013   NEBRASKA      GARDEN   55.3
# 5  2014   MISSOURI   CHRISTIAN   30.3
# 6  2014   NEBRASKA      GARDEN   56.3
# 7  2020   MISSOURI   CHRISTIAN   34.4

# %% [markdown]
# <span style=color:blue>For this exercise, we will drop these year-state-county triples from consideration.  A more thorough approach would be to focus on these year-state-county pairs (and perhaps the other ones with < 20 lon-lats), and randomly generate more lon-lats within the county until at least a few are found inside soybean fields.  (On the one hand, there have to be some if there was a yield ... however, CropScape is not perfect and may not have identified them accurately.)</span>
